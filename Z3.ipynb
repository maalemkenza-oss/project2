# %%
from z3 import *

# %%
s = Solver() # create a solver s

# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
import networkx.algorithms.isomorphism as iso

# %%
G = nx.Graph()

# %%
G= nx.read_adjlist("queen.adjlist",nodetype=int)

# %%
nx.draw(G,with_labels = True)

# %%
nn=G.number_of_nodes()

# %%
le=list(G.edges)

# %%
A=[G.adj[i] for i in range(nn)]

# %%
N=[list(i) for i in A]

# %%
ln=list(G.nodes)

# %%
def Diff(li1, li2):
    return (list(list(set(li1)-set(li2)) + list(set(li2)-set(li1))))

# %%
complement=[ Diff(ln,e)for e in N]

# %%
spec2=[BitVec('V'+str(j+1), nn+1) for j in range(nn)]# for 4 queen change  nn
#           by nn+1

# %%
spec2
# Out:
# [V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16]

# %%
for j in range(nn):
    p=2**j
    s.add(spec2[j]&p==p)

# %%
for i in range(nn):
    for j in N[i]:
        if i >j :
            s.add(spec2[j]&spec2[i]==0)

# %%
for i in range(nn):
    for j in complement[i]:
        if i >j :
            s.add(spec2[j]&spec2[i]!=0)

# %%
for i in range(nn):
    for j in range(nn):
        if i !=j :
            s.add(spec2[j]!=spec2[i])

# %%
s
# Out:
# [V1 & 1 == 1,
#  V2 & 2 == 2,
#  V3 & 4 == 4,
#  V4 & 8 == 8,
#  V5 & 16 == 16,
#  V6 & 32 == 32,
#  V7 & 64 == 64,
#  V8 & 128 == 128,
#  V9 & 256 == 256,
#  V10 & 512 == 512,
#  V11 & 1024 == 1024,
#  V12 & 2048 == 2048,
#  V13 & 4096 == 4096,
#  V14 & 8192 == 8192,
#  V15 & 16384 == 16384,
#  V16 & 32768 == 32768,
#  V3 & V5 == 0,
#  V4 & V5 == 0,
#  V4 & V6 == 0,
#  V1 & V7 == 0,
#  V1 & V8 == 0,
#  V2 & V8 == 0,
#  V2 & V9 == 0,
#  V4 & V9 == 0,
#  V7 & V9 == 0,
#  V8 & V9 == 0,
#  V1 & V10 == 0,
#  V3 & V10 == 0,
#  V8 & V10 == 0,
#  V2 & V11 == 0,
#  V4 & V11 == 0,
#  V5 & V11 == 0,
#  V1 & V12 == 0,
#  V3 & V12 == 0,
#  V5 & V12 == 0,
#  V6 & V12 == 0,
#  V2 & V13 == 0,
#  V3 & V13 == 0,
#  V6 & V13 == 0,
#  V8 & V13 == 0,
#  V11 & V13 == 0,
#  V12 & V13 == 0,
#  V1 & V14 == 0,
#  V3 & V14 == 0,
#  V4 & V14 == 0,
#  V5 & V14 == 0,
#  V7 & V14 == 0,
#  V12 & V14 == 0,
#  V1 & V15 == 0,
#  V2 & V15 == 0,
#  V4 & V15 == 0,
#  V6 & V15 == 0,
#  V8 & V15 == 0,
#  V9 & V15 == 0,
#  V2 & V16 == 0,
#  V3 & V16 == 0,
#  V5 & V16 == 0,
#  V7 & V16 == 0,
#  V9 & V16 == 0,
#  V10 & V16 == 0,
#  V1 & V2 != 0,
#  V1 & V3 != 0,
#  V2 & V3 != 0,
#  V1 & V4 != 0,
#  V2 & V4 != 0,
#  V3 & V4 != 0,
#  V1 & V5 != 0,
#  V2 & V5 != 0,
#  V1 & V6 != 0,
#  V2 & V6 != 0,
#  V3 & V6 != 0,
#  V5 & V6 != 0,
#  V2 & V7 != 0,
#  V3 & V7 != 0,
#  V4 & V7 != 0,
#  V5 & V7 != 0,
#  V6 & V7 != 0,
#  V3 & V8 != 0,
#  V4 & V8 != 0,
#  V5 & V8 != 0,
#  V6 & V8 != 0,
#  V7 & V8 != 0,
#  V1 & V9 != 0,
#  V3 & V9 != 0,
#  V5 & V9 != 0,
#  V6 & V9 != 0,
#  V2 & V10 != 0,
#  V4 & V10 != 0,
#  V5 & V10 != 0,
#  V6 & V10 != 0,
#  V7 & V10 != 0,
#  V9 & V10 != 0,
#  V1 & V11 != 0,
#  V3 & V11 != 0,
#  V6 & V11 != 0,
#  V7 & V11 != 0,
#  V8 & V11 != 0,
#  V9 & V11 != 0,
#  V10 & V11 != 0,
#  V2 & V12 != 0,
#  V4 & V12 != 0,
#  V7 & V12 != 0,
#  V8 & V12 != 0,
#  V9 & V12 != 0,
#  V10 & V12 != 0,
#  V11 & V12 != 0,
#  V1 & V13 != 0,
#  V4 & V13 != 0,
#  V5 & V13 != 0,
#  V7 & V13 != 0,
#  V9 & V13 != 0,
#  V10 & V13 != 0,
#  V2 & V14 != 0,
#  V6 & V14 != 0,
#  V8 & V14 != 0,
#  V9 & V14 != 0,
#  V10 & V14 != 0,
#  V11 & V14 != 0,
#  V13 & V14 != 0,
#  V3 & V15 != 0,
#  V5 & V15 != 0,
#  V7 & V15 != 0,
#  V10 & V15 != 0,
#  V11 & V15 != 0,
#  V12 & V15 != 0,
#  V13 & V15 != 0,
#  V14 & V15 != 0,
#  V1 & V16 != 0,
#  V4 & V16 != 0,
#  ...]

# %%
s.check()
# Out:
# sat

# %%
m=s.model()

# %%
len(m)
# Out:
# 16

# %%
m
# Out:
# [V7 = 706,
#  V9 = 6404,
#  V5 = 4625,
#  V1 = 69637,
#  V10 = 11016,
#  V12 = 18504,
#  V15 = 50688,
#  V4 = 65610,
#  V8 = 240,
#  V16 = 114720,
#  V6 = 8372,
#  V14 = 41248,
#  V2 = 8203,
#  V11 = 52356,
#  V13 = 70400,
#  V3 = 1158]

# %%
coding=[]

for i in range(len(m)):
     coding.append(0)

for i in range(len(m)):
    coding[i]=str(m[spec2[i]])

# %%
coding
# Out:
# ['69637',
#  '8203',
#  '1158',
#  '65610',
#  '4625',
#  '8372',
#  '706',
#  '240',
#  '6404',
#  '11016',
#  '52356',
#  '18504',
#  '70400',
#  '41248',
#  '50688',
#  '114720']

# %%
import pickle

# define a list of places
placesList = coding

with open('coding.data', 'wb') as filehandle:
    # store the data as binary data stream
    pickle.dump(placesList, filehandle)

# %%
import pickle

with open('coding.data', 'rb') as filehandle:
    # read the data as binary data stream
    placesList2 = pickle.load(filehandle)

# %%
l=[]
for i in range(len(coding)):
    l.append(int(placesList2[i]))

# %%
#numberofqueen=math.sqrt(nn)

#print(" my reprsentation for ",numberofqueen,"queen is :" ,  l)
print(l)
# Out:
# [69637, 8203, 1158, 65610, 4625, 8372, 706, 240, 6404, 11016, 52356, 18504, 70400, 41248, 50688, 114720]
